# %% [markdown]
# <a href="https://colab.research.google.com/github/nimrashaheen001/Programming_for_AI/blob/main/MMGLF03_thesis(basepapercodeMMGL)ADNI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = '/content/MMGL.zip'
extract_path = '/content/MMGL'

if zipfile.is_zipfile(zip_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Extraction complete.")
else:
    print("❌ The file is not a valid zip file.")
# Out:
# Extraction complete.

# %%
# !pip install SimpleITK
# Out:
# Collecting SimpleITK
#   Downloading simpleitk-2.5.2-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.2 kB)
# Downloading simpleitk-2.5.2-cp311-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (52.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.5.2

# %%
import os
import pandas as pd

# Path to training DICOM folders
dicom_root = "/content/MMGL/MMGLF/MMGLF/dataset/train"

# Path to tabular metadata CSV
csv_path = "/content/MMGL/MMGLF/MMGLF/dataset/tabular.csv"

# Output .txt path
output_txt = "/content/MMGL/MMGLF/MMGLF/train-oasis.txt"

# Load tabular data
df = pd.read_csv(csv_path)

# Create train-oasis.txt
with open(output_txt, 'w') as f:
    for subject in os.listdir(dicom_root):
        subject_path = os.path.join(dicom_root, subject)
        if not os.path.isdir(subject_path):
            continue
        row = df[df["PTID"] == subject]
        if not row.empty:
            cdr = float(row.iloc[0]["CDR"])
            label = 1 if cdr >= 0.5 else 0
            f.write(f"{subject_path} {label}\n")

print("✅ Created:", output_txt)
# Out:
# ✅ Created: /content/MMGL/MMGLF/MMGLF/train-oasis.txt

# %%
# For val-oasis.txt
val_dicom_root = "/content/MMGL/MMGLF/MMGLF/dataset/val"
val_output_txt = "/content/MMGL/MMGLF/MMGLF/val-oasis.txt"

with open(val_output_txt, 'w') as f:
    for subject in os.listdir(val_dicom_root):
        subject_path = os.path.join(val_dicom_root, subject)
        if not os.path.isdir(subject_path):
            continue
        row = df[df["PTID"] == subject]
        if not row.empty:
            cdr = float(row.iloc[0]["CDR"])
            label = 1 if cdr >= 0.5 else 0
            f.write(f"{subject_path} {label}\n")

print("✅ Created:", val_output_txt)
# Out:
# ✅ Created: /content/MMGL/MMGLF/MMGLF/val-oasis.txt

# %%
import pandas as pd
df = pd.read_csv("/content/MMGL/MMGLF/MMGLF/dataset/tabular.csv")   # your actual path
print(df.columns)
# Out:
# Index(['image_path', 'class', 'age', 'sex', 'years_in_education', 'APoe4',
#        'Abeta', 'P-tau181', 'T-tau'],
#       dtype='object')

# %%
# !ls -R /content/MMGL/MMGLF/MMGLF/dataset/train | head -n 50
# Out:
# /content/MMGL/MMGLF/MMGLF/dataset/train:
# OAS1_0001_MR1_mpr-1_100.jpg
# OAS1_0001_MR1_mpr-1_101.jpg
# OAS1_0001_MR1_mpr-1_102.jpg
# OAS1_0001_MR1_mpr-1_103.jpg
# OAS1_0001_MR1_mpr-1_104.jpg
# OAS1_0001_MR1_mpr-1_105.jpg
# OAS1_0001_MR1_mpr-1_106.jpg
# OAS1_0001_MR1_mpr-1_107.jpg
# OAS1_0001_MR1_mpr-1_108.jpg
# OAS1_0001_MR1_mpr-1_109.jpg
# OAS1_0001_MR1_mpr-1_110.jpg
# OAS1_0001_MR1_mpr-1_111.jpg
# OAS1_0001_MR1_mpr-1_112.jpg
# OAS1_0001_MR1_mpr-1_113.jpg
# OAS1_0001_MR1_mpr-1_114.jpg
# OAS1_0001_MR1_mpr-1_115.jpg
# OAS1_0001_MR1_mpr-1_116.jpg
# OAS1_0001_MR1_mpr-1_117.jpg
# OAS1_0001_MR1_mpr-1_118.jpg
# OAS1_0001_MR1_mpr-1_119.jpg
# OAS1_0001_MR1_mpr-1_120.jpg
# OAS1_0001_MR1_mpr-1_121.jpg
# OAS1_0001_MR1_mpr-1_122.jpg
# OAS1_0003_MR1_mpr-1_100.jpg
# OAS1_0003_MR1_mpr-1_101.jpg
# OAS1_0003_MR1_mpr-1_102.jpg
# OAS1_0003_MR1_mpr-1_103.jpg
# OAS1_0003_MR1_mpr-1_104.jpg
# OAS1_0003_MR1_mpr-1_105.jpg
# OAS1_0003_MR1_mpr-1_106.jpg
# OAS1_0003_MR1_mpr-1_107.jpg
# OAS1_0003_MR1_mpr-1_108.jpg
# OAS1_0003_MR1_mpr-1_109.jpg
# OAS1_0003_MR1_mpr-1_110.jpg
# OAS1_0003_MR1_mpr-1_111.jpg
# OAS1_0003_MR1_mpr-1_112.jpg
# OAS1_0003_MR1_mpr-1_113.jpg
# OAS1_0003_MR1_mpr-1_114.jpg
# OAS1_0003_MR1_mpr-1_115.jpg
# OAS1_0003_MR1_mpr-1_116.jpg
# OAS1_0003_MR1_mpr-1_117.jpg
# OAS1_0003_MR1_mpr-1_118.jpg
# OAS1_0003_MR1_mpr-1_119.jpg
# OAS1_0003_MR1_mpr-1_120.jpg
# OAS1_0003_MR1_mpr-1_121.jpg
# OAS1_0003_MR1_mpr-1_122.jpg
# OAS1_0028_MR1_mpr-1_100.jpg
# OAS1_0028_MR1_mpr-1_101.jpg
# OAS1_0028_MR1_mpr-1_102.jpg

# %%
import os
import pandas as pd
from glob import glob

# Paths
csv_path = "/content/MMGL/MMGLF/MMGLF/dataset/tabular.csv"
train_dir = "/content/MMGL/MMGLF/MMGLF/dataset/train"

# Load CSV
df = pd.read_csv(csv_path)

# Create a column with filename (without extension) from image_path
df['image_filename'] = df['image_path'].apply(lambda x: os.path.splitext(os.path.basename(str(x).strip()))[0])

print("🧾 Sample image filenames from CSV:")
print(df['image_filename'].head())

# Look for JPG files in train folder
image_files = glob(os.path.join(train_dir, "*.jpg"))
print(f"\n📂 Found {len(image_files)} jpg files in train folder:")
for f in image_files[:5]:
    print(os.path.basename(f))

# Match with CSV
print("\n🔍 Matching file names to CSV image filenames:")
for f in image_files[:5]:
    filename = os.path.splitext(os.path.basename(f))[0]
    print(f"File ID: {filename}", "✅ Match" if filename in df['image_filename'].values else "❌ No Match")
# Out:
# 🧾 Sample image filenames from CSV:
# 0    OAS1_0003_MR1_mpr-1_100
# 1    OAS1_0003_MR1_mpr-1_101
# 2    OAS1_0003_MR1_mpr-1_102
# 3    OAS1_0003_MR1_mpr-1_103
# 4    OAS1_0003_MR1_mpr-1_104
# Name: image_filename, dtype: object
#
# 📂 Found 69 jpg files in train folder:
# OAS1_0028_MR1_mpr-1_108.jpg
# OAS1_0003_MR1_mpr-1_122.jpg
# OAS1_0001_MR1_mpr-1_119.jpg
# OAS1_0001_MR1_mpr-1_108.jpg
# OAS1_0028_MR1_mpr-1_112.jpg
#
# 🔍 Matching file names to CSV image filenames:
# File ID: OAS1_0028_MR1_mpr-1_108 ✅ Match
# File ID: OAS1_0003_MR1_mpr-1_122 ✅ Match
# File ID: OAS1_0001_MR1_mpr-1_119 ✅ Match
# File ID: OAS1_0001_MR1_mpr-1_108 ✅ Match
# File ID: OAS1_0028_MR1_mpr-1_112 ✅ Match

# %%
import os
import pandas as pd
from glob import glob

# Define paths
base_path = "/content/MMGL/MMGLF/MMGLF/dataset"
csv_path = os.path.join(base_path, "tabular.csv")
train_dir = os.path.join(base_path, "train")
val_dir = os.path.join(base_path, "val")
train_txt = "/content/MMGL/MMGLF/MMGLF/train-oasis.txt"
val_txt = "/content/MMGL/MMGLF/MMGLF/val-oasis.txt"

# Load CSV
df = pd.read_csv(csv_path)

# Extract filename from image_path
df['image_filename'] = df['image_path'].apply(lambda x: os.path.splitext(os.path.basename(str(x).strip()))[0])

# Map classes to numeric labels
mapping = {
    'CN': 0,
    'MCI': 1,
    'AD': 2
}
df['label'] = df['class'].map(mapping)
df = df.dropna(subset=['label'])  # remove unknowns
df['label'] = df['label'].astype(int)

# Helper function to create txt file
def create_txt(data_dir, output_txt, df):
    with open(output_txt, 'w') as f:
        image_files = glob(os.path.join(data_dir, "*.jpg"))
        for file_path in image_files:
            filename = os.path.splitext(os.path.basename(file_path))[0]
            if filename in df['image_filename'].values:
                label = int(df[df['image_filename'] == filename].iloc[0]['label'])
                f.write(f"{file_path} {label}\n")

# Create txt files
create_txt(train_dir, train_txt, df)
create_txt(val_dir, val_txt, df)

print("✅ Created:")
print("   -", train_txt)
print("   -", val_txt)
# Out:
# ✅ Created:
#    - /content/MMGL/MMGLF/MMGLF/train-oasis.txt
#    - /content/MMGL/MMGLF/MMGLF/val-oasis.txt

# %%
# !head /content/MMGL/MMGLF/MMGLF/train-oasis.txt
# Out:
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_108.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_122.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_119.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_108.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_112.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_120.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_106.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_121.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_107.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_118.jpg 1

# %%
# !head /content/MMGL/MMGLF/MMGLF/train-oasis.txt
# Out:
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_108.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_122.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_119.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_108.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_112.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_120.jpg 1
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0001_MR1_mpr-1_106.jpg 0
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_121.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0003_MR1_mpr-1_107.jpg 2
# /content/MMGL/MMGLF/MMGLF/dataset/train/OAS1_0028_MR1_mpr-1_118.jpg 1

# %%
import os
from glob import glob

# Check how many patient folders exist
train_root = "/content/MMGL/MMGLF/MMGLF/dataset/train"
print("📂 Total patient folders in train:", len(os.listdir(train_root)))

# Check one folder has DICOMs
sample = os.listdir(train_root)[0]
sample_path = os.path.join(train_root, sample)
dicoms = glob(os.path.join(sample_path, "*.dcm"))
print(f"📄 Found {len(dicoms)} DICOMs in sample folder: {sample}")
# Out:
# 📂 Total patient folders in train: 69
# 📄 Found 0 DICOMs in sample folder: OAS1_0028_MR1_mpr-1_108.jpg

# %%
# !python /content/MMGL/MMGLF/MMGLF/train-test.py
# Out:
# Using device: cuda
# Train size: 69, Val size: 15
# epoch 0/29
# ----------
# epoch 1/30: 100% 8/8 [00:00<00:00, 10.61batch/s]
# Train AUC: 0.4781116816000537
# Validation Acc: 0.2000
# Val AUC: 0.5484126984126985
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 0.4667
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.75), np.float64(0.625), np.float64(0.375)]
# Specificity: [np.float64(1.0), np.float64(1.0), np.float64(0.2857142857142857)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       1.00      0.50      0.67         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.17      1.00      0.29         1
#
#     accuracy                           0.38         8
#    macro avg       0.39      0.50      0.32         8
# weighted avg       0.52      0.38      0.37         8
#
# Epoch: 001, Training: Loss: 15.3298, Accuracy: 28.9855%,
# 		Validation: Loss: 3.5211, Accuracy: 20.0000%, Time: 1.0070s
# Best Accuracy for validation : 0.2000 at epoch 001
# epoch 1/29
# ----------
# epoch 2/30: 100% 8/8 [00:00<00:00, 23.05batch/s]
# Train AUC: 0.5536075036075037
# Validation Acc: 0.2667
# Val AUC: 0.6220238095238095
# Class 0 ROC AUC: 0.4375
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.875)]
# Specificity: [np.float64(0.0), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      1.00      0.67         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.17      0.33      0.22         8
# weighted avg       0.25      0.50      0.33         8
#
# Epoch: 002, Training: Loss: 3.5002, Accuracy: 33.3333%,
# 		Validation: Loss: 1.0585, Accuracy: 26.6667%, Time: 0.4217s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 2/29
# ----------
# epoch 3/30: 100% 8/8 [00:00<00:00, 23.80batch/s]
# Train AUC: 0.5422077922077921
# Validation Acc: 0.2000
# Val AUC: 0.5956349206349206
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 0.7333
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.375), np.float64(0.875)]
# Specificity: [np.float64(1.0), np.float64(0.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.38      1.00      0.55         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.12      0.33      0.18         8
# weighted avg       0.14      0.38      0.20         8
#
# Epoch: 003, Training: Loss: 3.9146, Accuracy: 42.0290%,
# 		Validation: Loss: 1.0620, Accuracy: 20.0000%, Time: 0.3934s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 3/29
# ----------
# epoch 4/30: 100% 8/8 [00:00<00:00, 24.35batch/s]
# Train AUC: 0.5292291687640525
# Validation Acc: 0.1333
# Val AUC: 0.3956349206349206
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 0.1333
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.375)]
# Specificity: [np.float64(0.5), np.float64(1.0), np.float64(0.42857142857142855)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      0.50      0.50         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.25         8
#    macro avg       0.17      0.17      0.17         8
# weighted avg       0.25      0.25      0.25         8
#
# Epoch: 004, Training: Loss: 3.1514, Accuracy: 36.2319%,
# 		Validation: Loss: 1.9770, Accuracy: 13.3333%, Time: 0.3847s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 4/29
# ----------
# epoch 5/30: 100% 8/8 [00:00<00:00, 23.49batch/s]
# Train AUC: 0.5479462398067049
# Validation Acc: 0.2000
# Val AUC: 0.5067460317460317
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 0.4667
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.375), np.float64(0.875)]
# Specificity: [np.float64(1.0), np.float64(0.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.38      1.00      0.55         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.12      0.33      0.18         8
# weighted avg       0.14      0.38      0.20         8
#
# Epoch: 005, Training: Loss: 2.4258, Accuracy: 40.5797%,
# 		Validation: Loss: 0.7827, Accuracy: 20.0000%, Time: 0.3971s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 5/29
# ----------
# epoch 6/30: 100% 8/8 [00:00<00:00, 23.68batch/s]
# Train AUC: 0.5245681978588462
# Validation Acc: 0.2000
# Val AUC: 0.44007936507936507
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 0.2667
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.625), np.float64(0.75)]
# Specificity: [np.float64(0.0), np.float64(1.0), np.float64(0.8571428571428571)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.43      0.75      0.55         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.14      0.25      0.18         8
# weighted avg       0.21      0.38      0.27         8
#
# Epoch: 006, Training: Loss: 2.5212, Accuracy: 31.8841%,
# 		Validation: Loss: 1.2218, Accuracy: 20.0000%, Time: 0.3971s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 6/29
# ----------
# epoch 7/30: 100% 8/8 [00:00<00:00, 23.44batch/s]
# Train AUC: 0.5284657203261854
# Validation Acc: 0.0667
# Val AUC: 0.503968253968254
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 0.3333
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.5), np.float64(0.375)]
# Specificity: [np.float64(0.75), np.float64(0.6), np.float64(0.42857142857142855)]
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.33      0.33      0.33         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.12         8
#    macro avg       0.11      0.11      0.11         8
# weighted avg       0.12      0.12      0.12         8
#
# Epoch: 007, Training: Loss: 2.1720, Accuracy: 30.4348%,
# 		Validation: Loss: 1.1171, Accuracy: 6.6667%, Time: 0.4040s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 7/29
# ----------
# epoch 8/30: 100% 8/8 [00:00<00:00, 23.41batch/s]
# Train AUC: 0.5642804001122915
# Validation Acc: 0.1333
# Val AUC: 0.46230158730158727
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 0.3333
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.625), np.float64(0.5)]
# Specificity: [np.float64(0.25), np.float64(1.0), np.float64(0.5714285714285714)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.40      0.50      0.44         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.25         8
#    macro avg       0.13      0.17      0.15         8
# weighted avg       0.20      0.25      0.22         8
#
# Epoch: 008, Training: Loss: 1.9417, Accuracy: 39.1304%,
# 		Validation: Loss: 0.7888, Accuracy: 13.3333%, Time: 0.3993s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 8/29
# ----------
# epoch 9/30: 100% 8/8 [00:00<00:00, 24.13batch/s]
# Train AUC: 0.5823601463136346
# Validation Acc: 0.1333
# Val AUC: 0.5275793650793651
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.4667
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.5), np.float64(0.5)]
# Specificity: [np.float64(1.0), np.float64(0.4), np.float64(0.5714285714285714)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.40      0.67      0.50         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.25         8
#    macro avg       0.13      0.22      0.17         8
# weighted avg       0.15      0.25      0.19         8
#
# Epoch: 009, Training: Loss: 1.6573, Accuracy: 37.6812%,
# 		Validation: Loss: 0.8250, Accuracy: 13.3333%, Time: 0.3871s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 9/29
# ----------
# epoch 10/30: 100% 8/8 [00:00<00:00, 21.68batch/s]
# Train AUC: 0.5931715529276506
# Validation Acc: 0.2667
# Val AUC: 0.4609126984126984
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.2667
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.875)]
# Specificity: [np.float64(0.0), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      1.00      0.67         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.17      0.33      0.22         8
# weighted avg       0.25      0.50      0.33         8
#
# Epoch: 010, Training: Loss: 1.7582, Accuracy: 39.1304%,
# 		Validation: Loss: 0.9139, Accuracy: 26.6667%, Time: 0.4287s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 10/29
# ----------
# epoch 11/30: 100% 8/8 [00:00<00:00, 24.37batch/s]
# Train AUC: 0.60641081611235
# Validation Acc: 0.1333
# Val AUC: 0.5678571428571428
# Class 0 ROC AUC: 0.8750
# Class 1 ROC AUC: 0.4000
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.375)]
# Specificity: [np.float64(0.75), np.float64(0.8), np.float64(0.42857142857142855)]
#               precision    recall  f1-score   support
#
#           AD       0.50      0.25      0.33         4
#           CN       0.50      0.33      0.40         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.25         8
#    macro avg       0.33      0.19      0.24         8
# weighted avg       0.44      0.25      0.32         8
#
# Epoch: 011, Training: Loss: 1.4628, Accuracy: 39.1304%,
# 		Validation: Loss: 0.6392, Accuracy: 13.3333%, Time: 0.3865s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 11/29
# ----------
# epoch 12/30: 100% 8/8 [00:00<00:00, 23.94batch/s]
# Train AUC: 0.6502705627705628
# Validation Acc: 0.2000
# Val AUC: 0.6123015873015872
# Class 0 ROC AUC: 0.8750
# Class 1 ROC AUC: 0.5333
# Class 2 ROC AUC: 0.4286
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.5), np.float64(0.875)]
# Specificity: [np.float64(0.75), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.14      0.33      0.20         8
# weighted avg       0.16      0.38      0.22         8
#
# Epoch: 012, Training: Loss: 1.2000, Accuracy: 42.0290%,
# 		Validation: Loss: 0.5769, Accuracy: 20.0000%, Time: 0.3906s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 12/29
# ----------
# epoch 13/30: 100% 8/8 [00:00<00:00, 23.00batch/s]
# Train AUC: 0.7127705627705628
# Validation Acc: 0.2667
# Val AUC: 0.6005952380952381
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.4000
# Class 2 ROC AUC: 0.7143
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.875)]
# Specificity: [np.float64(0.0), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      1.00      0.67         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.17      0.33      0.22         8
# weighted avg       0.25      0.50      0.33         8
#
# Epoch: 013, Training: Loss: 1.0856, Accuracy: 52.1739%,
# 		Validation: Loss: 0.7279, Accuracy: 26.6667%, Time: 0.4067s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 13/29
# ----------
# epoch 14/30: 100% 8/8 [00:00<00:00, 23.78batch/s]
# Train AUC: 0.7115981240981242
# Validation Acc: 0.2000
# Val AUC: 0.9333333333333332
# Class 0 ROC AUC: 1.0000
# Class 1 ROC AUC: 0.8000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.375), np.float64(0.875)]
# Specificity: [np.float64(1.0), np.float64(0.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.38      1.00      0.55         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.12      0.33      0.18         8
# weighted avg       0.14      0.38      0.20         8
#
# Epoch: 014, Training: Loss: 1.4180, Accuracy: 43.4783%,
# 		Validation: Loss: 0.6983, Accuracy: 20.0000%, Time: 0.3962s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 14/29
# ----------
# epoch 15/30: 100% 8/8 [00:00<00:00, 23.46batch/s]
# Train AUC: 0.7445240000901053
# Validation Acc: 0.2667
# Val AUC: 0.6287698412698413
# Class 0 ROC AUC: 0.5625
# Class 1 ROC AUC: 0.4667
# Class 2 ROC AUC: 0.8571
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.875)]
# Specificity: [np.float64(0.0), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      1.00      0.67         4
#           CN       0.00      0.00      0.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.17      0.33      0.22         8
# weighted avg       0.25      0.50      0.33         8
#
# Epoch: 015, Training: Loss: 1.1292, Accuracy: 47.8261%,
# 		Validation: Loss: 0.6199, Accuracy: 26.6667%, Time: 0.4052s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 15/29
# ----------
# epoch 16/30: 100% 8/8 [00:00<00:00, 24.06batch/s]
# Train AUC: 0.7623015873015874
# Validation Acc: 0.2000
# Val AUC: 0.8944444444444445
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 0.9333
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.5), np.float64(0.875)]
# Specificity: [np.float64(0.75), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.14      0.33      0.20         8
# weighted avg       0.16      0.38      0.22         8
#
# Epoch: 016, Training: Loss: 0.7974, Accuracy: 49.2754%,
# 		Validation: Loss: 0.5791, Accuracy: 20.0000%, Time: 0.3951s
# Best Accuracy for validation : 0.2667 at epoch 002
# epoch 16/29
# ----------
# epoch 17/30: 100% 8/8 [00:00<00:00, 24.11batch/s]
# Train AUC: 0.8462662337662338
# Validation Acc: 0.3333
# Val AUC: 0.7611111111111111
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 0.5333
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.625), np.float64(0.625), np.float64(1.0)]
# Specificity: [np.float64(0.25), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.57      1.00      0.73         4
#           CN       0.00      0.00      0.00         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.52      0.67      0.58         8
# weighted avg       0.41      0.62      0.49         8
#
# Epoch: 017, Training: Loss: 0.4783, Accuracy: 73.9130%,
# 		Validation: Loss: 0.4476, Accuracy: 33.3333%, Time: 0.4029s
# Best Accuracy for validation : 0.3333 at epoch 017
# epoch 17/29
# ----------
# epoch 18/30: 100% 8/8 [00:00<00:00, 24.08batch/s]
# Train AUC: 0.8358669754018591
# Validation Acc: 0.2000
# Val AUC: 0.9375
# Class 0 ROC AUC: 0.8125
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.375), np.float64(0.5), np.float64(0.875)]
# Specificity: [np.float64(0.75), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.14      0.33      0.20         8
# weighted avg       0.16      0.38      0.22         8
#
# Epoch: 018, Training: Loss: 0.5037, Accuracy: 62.3188%,
# 		Validation: Loss: 0.4392, Accuracy: 20.0000%, Time: 0.3893s
# Best Accuracy for validation : 0.3333 at epoch 017
# epoch 18/29
# ----------
# epoch 19/30: 100% 8/8 [00:00<00:00, 23.42batch/s]
# Train AUC: 0.8769925165274003
# Validation Acc: 0.4000
# Val AUC: 0.8736111111111112
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.9333
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.75), np.float64(0.75), np.float64(1.0)]
# Specificity: [np.float64(0.5), np.float64(1.0), np.float64(1.0)]
#               precision    recall  f1-score   support
#
#           AD       0.67      1.00      0.80         4
#           CN       1.00      0.33      0.50         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.75         8
#    macro avg       0.89      0.78      0.77         8
# weighted avg       0.83      0.75      0.71         8
#
# Epoch: 019, Training: Loss: 0.3850, Accuracy: 82.6087%,
# 		Validation: Loss: 0.3040, Accuracy: 40.0000%, Time: 0.4069s
# Best Accuracy for validation : 0.4000 at epoch 019
# epoch 19/29
# ----------
# epoch 20/30: 100% 8/8 [00:00<00:00, 23.26batch/s]
# Train AUC: 0.8662455115943488
# Validation Acc: 0.4667
# Val AUC: 0.8513888888888889
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.8667
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.875), np.float64(0.875), np.float64(1.0)]
# Specificity: [np.float64(0.75), np.float64(1.0), np.float64(1.0)]
#               precision    recall  f1-score   support
#
#           AD       0.80      1.00      0.89         4
#           CN       1.00      0.67      0.80         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.88         8
#    macro avg       0.93      0.89      0.90         8
# weighted avg       0.90      0.88      0.87         8
#
# Epoch: 020, Training: Loss: 0.3336, Accuracy: 88.4058%,
# 		Validation: Loss: 0.2870, Accuracy: 46.6667%, Time: 0.4291s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 20/29
# ----------
# epoch 21/30: 100% 8/8 [00:00<00:00, 23.89batch/s]
# Train AUC: 0.8903167055254654
# Validation Acc: 0.2667
# Val AUC: 0.8736111111111112
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.9333
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.625), np.float64(0.875)]
# Specificity: [np.float64(0.75), np.float64(0.4), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.50      0.25      0.33         4
#           CN       0.50      1.00      0.67         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.33      0.42      0.33         8
# weighted avg       0.44      0.50      0.42         8
#
# Epoch: 021, Training: Loss: 0.3036, Accuracy: 84.0580%,
# 		Validation: Loss: 0.3894, Accuracy: 26.6667%, Time: 0.3937s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 21/29
# ----------
# epoch 22/30: 100% 8/8 [00:00<00:00, 21.45batch/s]
# Train AUC: 0.8746602234974329
# Validation Acc: 0.4000
# Val AUC: 0.8333333333333334
# Class 0 ROC AUC: 0.5000
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.75), np.float64(0.75), np.float64(1.0)]
# Specificity: [np.float64(1.0), np.float64(0.6), np.float64(1.0)]
#               precision    recall  f1-score   support
#
#           AD       1.00      0.50      0.67         4
#           CN       0.60      1.00      0.75         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.75         8
#    macro avg       0.87      0.83      0.81         8
# weighted avg       0.85      0.75      0.74         8
#
# Epoch: 022, Training: Loss: 0.3570, Accuracy: 79.7101%,
# 		Validation: Loss: 0.2290, Accuracy: 40.0000%, Time: 0.4308s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 22/29
# ----------
# epoch 23/30: 100% 8/8 [00:00<00:00, 20.34batch/s]
# Train AUC: 0.9033127059107972
# Validation Acc: 0.2667
# Val AUC: 0.9375
# Class 0 ROC AUC: 0.8125
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.5), np.float64(1.0)]
# Specificity: [np.float64(1.0), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.48      0.67      0.53         8
# weighted avg       0.29      0.50      0.35         8
#
# Epoch: 023, Training: Loss: 0.2577, Accuracy: 86.9565%,
# 		Validation: Loss: 0.4336, Accuracy: 26.6667%, Time: 0.4810s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 23/29
# ----------
# epoch 24/30: 100% 8/8 [00:00<00:00, 15.74batch/s]
# Train AUC: 0.9188311688311689
# Validation Acc: 0.3333
# Val AUC: 0.8513888888888889
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.8667
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.625), np.float64(0.625), np.float64(1.0)]
# Specificity: [np.float64(0.25), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.57      1.00      0.73         4
#           CN       0.00      0.00      0.00         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.52      0.67      0.58         8
# weighted avg       0.41      0.62      0.49         8
#
# Epoch: 024, Training: Loss: 0.2772, Accuracy: 81.1594%,
# 		Validation: Loss: 0.5766, Accuracy: 33.3333%, Time: 0.5957s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 24/29
# ----------
# epoch 25/30: 100% 8/8 [00:00<00:00, 16.32batch/s]
# Train AUC: 0.9038831735014132
# Validation Acc: 0.2667
# Val AUC: 0.9166666666666666
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.5), np.float64(1.0)]
# Specificity: [np.float64(1.0), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.48      0.67      0.53         8
# weighted avg       0.29      0.50      0.35         8
#
# Epoch: 025, Training: Loss: 0.2789, Accuracy: 85.5072%,
# 		Validation: Loss: 0.4118, Accuracy: 26.6667%, Time: 0.5793s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 25/29
# ----------
# epoch 26/30: 100% 8/8 [00:00<00:00, 16.14batch/s]
# Train AUC: 0.9185734439301111
# Validation Acc: 0.2667
# Val AUC: 0.875
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.5), np.float64(1.0)]
# Specificity: [np.float64(1.0), np.float64(0.2), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.43      1.00      0.60         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.50         8
#    macro avg       0.48      0.67      0.53         8
# weighted avg       0.29      0.50      0.35         8
#
# Epoch: 026, Training: Loss: 0.2646, Accuracy: 84.0580%,
# 		Validation: Loss: 0.3434, Accuracy: 26.6667%, Time: 0.5889s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 26/29
# ----------
# epoch 27/30: 100% 8/8 [00:00<00:00, 16.26batch/s]
# Train AUC: 0.9026695526695526
# Validation Acc: 0.2000
# Val AUC: 0.875
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.5), np.float64(0.375), np.float64(0.875)]
# Specificity: [np.float64(1.0), np.float64(0.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.00      0.00      0.00         4
#           CN       0.38      1.00      0.55         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.38         8
#    macro avg       0.12      0.33      0.18         8
# weighted avg       0.14      0.38      0.20         8
#
# Epoch: 027, Training: Loss: 0.1863, Accuracy: 91.3043%,
# 		Validation: Loss: 0.8675, Accuracy: 20.0000%, Time: 0.5491s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 27/29
# ----------
# epoch 28/30: 100% 8/8 [00:00<00:00, 23.31batch/s]
# Train AUC: 0.9446625725695493
# Validation Acc: 0.3333
# Val AUC: 0.8736111111111112
# Class 0 ROC AUC: 0.6875
# Class 1 ROC AUC: 0.9333
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.625), np.float64(0.625), np.float64(1.0)]
# Specificity: [np.float64(0.25), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.57      1.00      0.73         4
#           CN       0.00      0.00      0.00         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.52      0.67      0.58         8
# weighted avg       0.41      0.62      0.49         8
#
# Epoch: 028, Training: Loss: 0.1533, Accuracy: 92.7536%,
# 		Validation: Loss: 0.4138, Accuracy: 33.3333%, Time: 0.4020s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 28/29
# ----------
# epoch 29/30: 100% 8/8 [00:00<00:00, 23.38batch/s]
# Train AUC: 0.8964646464646465
# Validation Acc: 0.4000
# Val AUC: 0.9166666666666666
# Class 0 ROC AUC: 0.7500
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.75), np.float64(0.75), np.float64(1.0)]
# Specificity: [np.float64(1.0), np.float64(0.6), np.float64(1.0)]
#               precision    recall  f1-score   support
#
#           AD       1.00      0.50      0.67         4
#           CN       0.60      1.00      0.75         3
#          MCI       1.00      1.00      1.00         1
#
#     accuracy                           0.75         8
#    macro avg       0.87      0.83      0.81         8
# weighted avg       0.85      0.75      0.74         8
#
# Epoch: 029, Training: Loss: 0.2967, Accuracy: 81.1594%,
# 		Validation: Loss: 0.2159, Accuracy: 40.0000%, Time: 0.4007s
# Best Accuracy for validation : 0.4667 at epoch 020
# epoch 29/29
# ----------
# epoch 30/30: 100% 8/8 [00:00<00:00, 22.34batch/s]
# Train AUC: 0.9349747474747474
# Validation Acc: 0.4667
# Val AUC: 0.875
# Class 0 ROC AUC: 0.6250
# Class 1 ROC AUC: 1.0000
# Class 2 ROC AUC: 1.0000
# Figure(640x480)
# ACC: [np.float64(0.875), np.float64(1.0), np.float64(0.875)]
# Specificity: [np.float64(0.75), np.float64(1.0), np.float64(1.0)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#           AD       0.80      1.00      0.89         4
#           CN       1.00      1.00      1.00         3
#          MCI       0.00      0.00      0.00         1
#
#     accuracy                           0.88         8
#    macro avg       0.60      0.67      0.63         8
# weighted avg       0.78      0.88      0.82         8
#
# Epoch: 030, Training: Loss: 0.1662, Accuracy: 89.8551%,
# 		Validation: Loss: 0.2914, Accuracy: 46.6667%, Time: 0.4148s
# Best Accuracy for validation : 0.4667 at epoch 020
# Figure(640x480)
# Figure(640x480)

# %%
import shutil
from google.colab import files

# ✅ Step 1: Zip the folder
shutil.make_archive('/content/MMGLF-zipped', 'zip', '/content/MMGL/MMGLF/MMGLF')

# ✅ Step 2: Download the zip file
files.download('/content/MMGLF-zipped.zip')
