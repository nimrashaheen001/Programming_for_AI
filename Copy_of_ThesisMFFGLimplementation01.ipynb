# %% [markdown]
# <a href="https://colab.research.google.com/github/nimrashaheen001/Programming_for_AI/blob/main/Copy_of_ThesisMFFGLimplementation01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = '/content/MMGL.zip'
extract_path = '/content/MMGLF'

if zipfile.is_zipfile(zip_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Extraction complete.")
else:
    print("❌ The file is not a valid zip file.")
# Out:
# Extraction complete.

# %%
# !pip install SimpleITK
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 20.1 MB/s eta 0:00:00
# ...

# %%
# !python /content/MMGLF/train-test.py
# Out:
# Using device: cuda
# Train size: 2417, Val size: 565
# epoch 0/29
# ----------
# epoch 1/30: 100% 302/302 [00:15<00:00, 19.76batch/s]
# Train AUC: 0.48895451542987867
# Validation Acc: 0.2071
# Val AUC: 0.49976689998187845
# Class 0 ROC AUC: 0.4966
# Class 1 ROC AUC: 0.5024
# Class 2 ROC AUC: 0.5002
# Figure(640x480)
# ACC: [np.float64(0.7446428571428572), np.float64(0.4642857142857143), np.float64(0.20892857142857144)]
# Specificity: [np.float64(1.0), np.float64(1.0), np.float64(0.0022522522522522522)]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
with open("/content/MMGLF/train-oasis.txt") as f:
    for _ in range(10):
        print(f.readline().strip())
# Out:
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0004_MR1_mpr-3_111.jpg 0
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0035_MR1_mpr-2_131.jpg 1
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0052_MR1_mpr-1_127.jpg 1
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0003_MR1_mpr-2_137.jpg 2
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0004_MR1_mpr-2_156.jpg 0
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0021_MR1_mpr-2_149.jpg 2
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0001_MR1_mpr-3_117.jpg 0
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0003_MR1_mpr-3_142.jpg 2
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0031_MR1_mpr-2_156.jpg 1
# /content/MMGLF/MMGLF-zipped/dataset/train/OAS1_0021_MR1_mpr-4_101.jpg 2
